# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %%
zoster=pd.read_csv('zoster.csv')
zoster.columns=['PatientID','age','cen','date_string']
zoster['date']=pd.to_datetime(zoster.date_string)

# %%
zoster.head()
# Out:
#   PatientID        age       cen          date_string                date
# 0  censored  79.834490  censored  2010-01-13 16:19:01 2010-01-13 16:19:01
# 1  censored  66.855571  censored  2020-12-14 08:03:23 2020-12-14 08:03:23
# 2  censored  71.823033  censored  2021-02-17 17:18:34 2021-02-17 17:18:34
# 3  censored  85.470537  censored  2020-11-03 07:17:26 2020-11-03 07:17:26
# 4  censored  75.366517  censored  2019-03-31 23:52:56 2019-03-31 23:52:56

# %%
counts=zoster[['PatientID','date']].groupby(pd.Grouper(key='date', freq='1M')).count()
# Out:
#             PatientID
# date
# 2007-06-30          3
# 2007-07-31          4
# 2007-08-31          2
# 2007-09-30          0
# 2007-10-31          3
# ...               ...
# 2020-10-31         36
# 2020-11-30         27
# 2020-12-31         39
# 2021-01-31         39
# 2021-02-28         16
#
# [165 rows x 1 columns]

# %%
plt.plot(counts.index,counts.PatientID)
plt.title('zoster diagnosis per month')
plt.show()

# %%
months=['MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC','JAN','FEB']
last_year=counts[-12:]
before_year=counts[-24:-12]

# %%
plt.plot(months,last_year.PatientID)
plt.plot(months,before_year.PatientID)
plt.legend(labels=['2020-2021','2019-2020'])
plt.title('zoster diagnosis per month')
plt.show()
